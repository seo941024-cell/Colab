# %% [markdown]
# <a href="https://colab.research.google.com/github/seo941024-cell/Colab/blob/master/%EC%BD%94%EB%94%A9%ED%85%8C%EC%8A%A4%ED%8A%B8_%EB%AC%B8%EC%A0%9C%ED%92%80%EC%9D%B4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def solution(num_list, n):
    answer = []
    for i in range(0, len(num_list), n):
        answer.append(num_list[i])

    return answer

# %%
def solution(num_list, n):
    answer = []
    for i in range(0,n,1) :
        answer.append(num_list[i])
    return answer

# %%
def solution(num_list,n):
    answer = []
    for i in range(n-1,len(num_list),1):
        answer.append(num_list[i])
    return answer

# %%
def solution(my_string, n):
    answer = ''
    for i in range(0,n,1):
        answer += my_string[i]
    return answer

# %%
def solution(my_string, index_list):
    answer = ''
    for i in index_list :
            answer += my_string[i]
    return answer

# %%
def solution(start_num, end_num):
    answer = []
    for i in range(start_num,end_num+1,1) :
        answer.append([i])
    return answer
